# %%
import pandas
import matplotlib.pyplot as plt
import seaborn
import numpy

from sklearn.linear_model import LinearRegression
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 3
#       1 import pandas
#       2 import matplotlib.pyplot as plt
# ----> 3 import seaborn
#       4 import numpy
#       6 from sklearn.linear_model import LinearRegression
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
path_csv = "./number of travelers.csv"
dataset_df = pandas.read_csv(path_csv, sep=",")

# %%
dataset_df.head()
# Out:
#         month  passengers
# 0  2000-01-01       46492
# 1  2000-02-01       48526
# 2  2000-03-01       58764
# 3  2000-04-01       56033
# 4  2000-05-01       58201

# %%
plt.figure(figsize=(15, 6))
plt.plot(dataset_df.index, dataset_df["passengers"])
plt.show()

# %%
dataset_df["index_time"] = numpy.arange(1, len(dataset_df)+1, 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 dataset_df["index_time"] = numpy.arange(1, len(dataset_df)+1, 1)
#
# NameError: name 'numpy' is not defined

# %%
dataset_mean, dataset_std = dataset_df["passengers"].mean(), dataset_df["passengers"].std()
dataset_df["passengers"] = (dataset_df["passengers"] - dataset_mean)/dataset_std

# %%
dataset_df
# Out:
#           month  passengers
# 0    2000-01-01   -1.820131
# 1    2000-02-01   -1.585390
# 2    2000-03-01   -0.403839
# 3    2000-04-01   -0.719020
# 4    2000-05-01   -0.468814
# ..          ...         ...
# 235  2019-08-01    2.483678
# 236  2019-09-01    1.191797
# 237  2019-10-01    1.887363
# 238  2019-11-01    1.247655
# 239  2019-12-01    1.966418
#
# [240 rows x 2 columns]

# %%
dataset_length = len(dataset_df)
index_split = int(dataset_length*0.75)
train_df = dataset_df[ : index_split]
test_df = dataset_df[index_split: ]

# %%
x_train = train_df[["index_time"]].values
y_train = train_df[["passengers"]].values


x_test = test_df[["index_time"]].values
y_test = test_df[["passengers"]].values
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 x_train = train_df[["index_time"]].values
#       2 y_train = train_df[["passengers"]].values
#       5 x_test = test_df[["index_time"]].values
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:5876, in Index._get_indexer_strict(self, key, axis_name)
#    5873 else:
#    5874     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5876 self._raise_if_missing(keyarr, indexer, axis_name)
#    5878 keyarr = self.take(indexer)
#    5879 if isinstance(key, Index):
#    5880     # GH 42790 - Preserve name from an Index
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:5935, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5933     if use_interval_msg:
#    5934         key = list(key)
# -> 5935     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5937 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    5938 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['index_time'], dtype='object')] are in the [columns]"

# %%
model_passenger_prediction = LinearRegression()

# %%
model_passenger_prediction.fit(x_train, y_train)

# %%
y_test_predicted  = model_passenger_prediction.predict(x_test)
y_train_predicted = model_passenger_prediction.predict(x_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 y_test_predicted  = model_passenger_prediction.predict(x_test)
#       2 y_train_predicted = model_passenger_prediction.predict(x_train)
#
# NameError: name 'model_passenger_prediction' is not defined

# %%
y_train  = y_train*dataset_std + dataset_mean
y_test  = y_test*dataset_std + dataset_mean


y_train_predicted  = y_train_predicted*dataset_std + dataset_mean
y_test_predicted  = y_test_predicted*dataset_std + dataset_mean


plt.figure(figsize=(15,6))
plt.plot(x_train, y_train, "ro")
plt.plot(x_train, y_train_predicted, "b-")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 y_train  = y_train*dataset_std + dataset_mean
#       2 y_test  = y_test*dataset_std + dataset_mean
#       5 y_train_predicted  = y_train_predicted*dataset_std + dataset_mean
#
# NameError: name 'y_train' is not defined
